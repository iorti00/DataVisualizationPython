# %% [markdown]
# ## A step-by-step guide to Data Visualizations in Python
#
# Follow along with [this article](https://medium.com/codex/step-by-step-guide-to-data-visualizations-in-python-b322129a1540).  We will be using [this .xlsx dataset](https://www.kaggle.com/roshansharma/immigration-to-canada-ibm-dataset) from Kaggle on Immigration to Canada from 1980–2013. No need to dowload it, it is already in the git repositroy you forked.<br>
#
# #### We suggest that instead of copy and pasting the code, you type it out.  This will help you become more familiar with the syntex and better understand it.

# %% [markdown]
# ### Step-1: Importing Packages

# %%
#import all librarys and modules needed
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style
import mplcyberpunk as mplcp
import wordcloud as wc


#setting style for graphs
style.use('ggplot')
plt.rcParams['figure.figsize'] = (20,10)

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\ortiz\anaconda3\lib\site-packages (1.8.2.2)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in c:\users\ortiz\anaconda3\lib\site-packages (from wordcloud) (9.0.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ortiz\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: matplotlib in c:\users\ortiz\anaconda3\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\ortiz\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
pip install Pywaffle
# Out:
# Requirement already satisfied: Pywaffle in c:\users\ortiz\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\ortiz\anaconda3\lib\site-packages (from Pywaffle) (3.5.1)
# Requirement already satisfied: fontawesomefree in c:\users\ortiz\anaconda3\lib\site-packages (from Pywaffle) (6.2.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (9.0.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ortiz\anaconda3\lib\site-packages (from matplotlib->Pywaffle) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\ortiz\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->Pywaffle) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step-2 : Importing and Cleaning Data

# %%
#import and clean data, remember path is data/Canada.xlsx

df = pd.read_excel('data/Canada.xlsx',1, skiprows = range(20), skipfooter = 2)

df.drop(['AREA','REG','DEV','Type','Coverage','DevName'], axis=1, inplace=True)
df.rename(columns = {'OdName':'country','AreaName':'continent','RegName':'region'}, inplace = True)
df['total'] = df.sum(axis = 1)
df = df.set_index('country')
df.rename(index = {'United Kingdom of Great Britain and Northern Ireland':'UK & Ireland'}, inplace = True)
df.columns = df.columns.astype(str)
# Useful for upcoming visualizations
years = list(map(str, range(1980,2013)))
# Out:
# C:\Users\ortiz\AppData\Local\Temp\ipykernel_36532\1527241349.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['total'] = df.sum(axis = 1)

# %% [markdown]
# ### Step-3 : Creating Beautiful Visualizations
#
# #### Line Chart

# %%
# Single line chart

fig1 = df.loc['Haiti', years].plot(kind = 'line', color = 'r')
plt.title('Immigration from Haiti to Canada from 1980-2013',color = 'black')
plt.xlabel('Years',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('linechart_single.png')

plt.show()

# %%
# Multiple Line chart 
plt.style.use('dark_background')
fig2 = plt.plot(df.loc['India',years], label = 'India')
plt.plot(df.loc['China',years], label = 'China')
plt.plot(df.loc['Philippines',years], label = 'Sri Lanka')
plt.legend(loc = 'upper left', fontsize = 20,  labelcolor='w')
plt.xticks(rotation = 90, color = 'white')
plt.yticks(color = 'w')
plt.title('Immigration to Canada from 1980-2013',color = 'w')
plt.xlabel('Year',color = 'w')
plt.ylabel('Number of Immigrants',color = 'w')
plt.savefig('linechart_multiple.png')

plt.show()

# %% [markdown]
# #### Lets talk about style

# %%
#Shows all avaiable built-in styles
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# To see a visualization of the aviable style sheets [click here](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
#
# Syntex to select a specific style is: plt.style.use('style_name')
#
# *Try it out by adding the line of code to the top of the code block above and choose one of the preinstalled styles. Which style is your favorite?*
#
# **I like the color palate for fivethirtyeight but want to find out how to adjust the color for the legend text.**
#
# *What happens when you change the line- plt.legend(loc = 'upper left', fontsize = 12) to plt.legend(loc = 'lower right', fontsize = 12)?*
#
# **loc gives us the location of the legend.The strings 'upper left', 'upper right', 'lower left', 'lower right' place the legend at the corresponding corner of the axes/figure. The string 'best' places the legend at the location, among the nine locations defined so far, with the minimum overlap with other drawn artists.**
#
#
# Experiment changing other lines of the code and see how the graph changes. Add any notes or observations here. Going forward feel free to experiment with each graph type<br><br><br><br><br><br>

# %% [markdown]
# #### Install mplcyberpunk
# Open a terminal window and at at the prompt type:
#
# python -V
#
# If its python 3.something, copy and paste: pip install mplcyberpunk
# If its python 2.something, copy and paste: pip3 install mplcyberpunk
#
#
# For more info on mplcyberpunk click [here.](https://github.com/dhaitz/mplcyberpunk)

# %%
# Cyberpunk Multiple Line Chart

style.use('cyberpunk')

plt.plot(df.loc['India',years], label = 'India')
plt.plot(df.loc['China',years], label = 'China')
plt.plot(df.loc['Philippines',years], label = 'Sri Lanka')
plt.legend(loc = 'upper left', fontsize = 14)
plt.xticks(rotation = 90, color = 'white', fontsize = 14, fontweight = 'bold')
plt.yticks(color = 'white', fontsize = 14, fontweight = 'bold')
plt.title('Immigration to Canada from 1980-2013',color = 'white', fontsize = 20, fontweight = 'bold')
plt.xlabel('Year',color = 'white', fontsize = 16, fontweight = 'bold')
plt.ylabel('Number of Immigrants',color = 'white',fontsize = 16, fontweight = 'bold')
plt.savefig('cyber_line.png')

plt.show()

# %% [markdown]
# #### Bar Chart

# %%
# Vertical bar chart
# Do not change the style back to ggplot 
# delete the style.use('ggplot') line of code

# Vertical
style.use('cyberpunk')
df_tot = pd.DataFrame(df.loc[:,years].sum())
df_tot.rename(columns = {0:'total'}, inplace = True)

df_tot.plot(kind = 'bar', legend = False)
plt.title('Total Immigrants to Canada from 1980-2013',color = 'white')
plt.xticks(color = 'white')
plt.yticks(color = 'white')
plt.xlabel('Year',color = 'white')
plt.ylabel('Number of Immigrants',color = 'white')
plt.savefig('bar_vertical.png')

plt.show()

# %% [markdown]
# Notice that style is still set to cyberpunk.  How do we fix it so we can see the labels?<br> <br>
#
# Answer: change the color = 'black' to 'white'
#
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **Each plt. corosponds with label part of the bar chart. Such as plt.title parameters make changes to the title, plt.ylable changes the y-axis lable, etc. Each has parameters that can be adjusted such as location, text size, text color, and label names etc.**
#
# **The plt.savefig method saves the current figure. .png is saving the figure as a .png. I can see that there is now .png files saved for the past figures as well now found within the directory Women+/DataVisualizationPython.**

# %%
# Horizontal bar chart
#change style back to ggplt

style.use('ggplot')
df_top10 = pd.DataFrame(df.nlargest(10,'total')['total'].sort_values(ascending = True))

df_top10.plot.barh(legend = False, color = 'crimson', edgecolor = 'lightcoral')
plt.title('Top 10 Immigrant Countries to Canada from 1980-2013',color = 'black')
plt.xlabel('Number of Immigrants',color = 'black')
plt.ylabel('Country',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('bar_horizontal.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **Adding in sort_values(ascending = True) is neat because it sorts the values in ascending order**

# %%
# Grouped bar chart

year_int10 = list(map(str, (1980,1990,2000,2010, 2013)))
df_group = pd.DataFrame(df.loc[['India','China','Philippines','Pakistan'],year_int10].T)

df_group.plot.bar(edgecolor = 'white')
plt.title('Total Immigrants to Canada from 1980-2013',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.legend(title = 'Country', fontsize = 12,  labelcolor='k')
plt.savefig('bar_grouped.png')

plt.show()

# %% [markdown]
# Notice how the labels in the legend have disapeared?  We can fix this by adding labelcolor='k' to plt.legend<br>
# <br>plt.legend(title = 'Country', fontsize = 12, labelcolor='black')

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Area Chart

# %%
# Area Chart
# simple area chart
style.use('ggplot')
plt.fill_between(df_tot.index, df_tot['total'], color="hotpink", alpha=.3)
plt.plot(df_tot.index, df_tot['total'], color = 'skyblue', alpha = 1)
plt.title('Total Immigrants to Canada from 1980-2013', fontsize = 18, color = 'black')
plt.yticks(fontsize = 12, color = 'black')
plt.xticks(fontsize = 12, rotation = 90, color = 'black')
plt.xlabel('Year', fontsize = 14, color = 'black')
plt.ylabel('Number of Immigrants', fontsize = 14, color = 'black')
plt.savefig('area_simple.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# cyberpunk simple area chart
# simple area chart
import mplcyberpunk

style.use('cyberpunk')

plt.fill_between(df_tot.index, df_tot['total'], color = 'yellowgreen', alpha = 0.1)
plt.plot(df_tot.index, df_tot['total'], color = 'palegreen', alpha = 1)
mplcyberpunk.add_glow_effects()
plt.title('Total Immigrants to Canada from 1980-2013', fontsize = 20,fontweight = 'bold', color = 'white')
plt.yticks(fontsize = 14, color = 'white',fontweight = 'bold')
plt.xticks(fontsize = 14, rotation = 90, color = 'white',fontweight = 'bold')
plt.xlabel('Year', fontsize = 16, color = 'white',fontweight = 'bold')
plt.ylabel('Number of Immigrants', fontsize = 16, color = 'white',fontweight = 'bold')
plt.savefig('cyber_area_simple.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here.
#
# **IT GLOOOOWWWSSSS, or at least it has the illusion of glowing. The alpah parameter adjusts the density of colors, with the value of 1 being the max**

# %%
# stacked area chart
style.use('ggplot')
color = ['skyblue','lightcoral']
top2_list = df.nlargest(2, 'total').index.tolist()
df_top2 = pd.DataFrame(df.loc[top2_list, years].T)

df_top2.plot(kind = 'area', stacked = True, color = color)

plt.title('Total Immigrants to Canada from 1980-2013',color = 'black')
plt.legend(fontsize = 12, labelcolor = "black")
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.xticks(color = 'black', fontsize = '12')
plt.yticks(color = 'black', fontsize = '20')
plt.savefig('area_stacked.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **Adding in the parameter for fontsize = in to the method plt.yticks & plt.xticks adjusts the label font size.**

# %%
# unstacked area chart
style.use('ggplot')


df_top2.plot(kind = 'area', stacked = False, color = 'hotpink')
plt.title('Total Immigrants to Canada from 1980-2013',color = 'black')
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Immigrants',color = 'black')
plt.legend(fontsize = 12, labelcolor = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('area_unstacked.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **In this instants, color = color is the default option?**

# %% [markdown]
# #### Box Plot

# %%
# Vertical Box Plot

df_box = pd.DataFrame(df.loc[['India','China','Pakistan','UK & Ireland','Philippines'], years].T)

df_box.plot(kind = 'box')
plt.title('Top 5 Immigrant Countries to Canada from 1980-2013', color = 'black', fontsize = '20')
plt.xlabel('Country', color = 'black', fontsize = '20')
plt.ylabel('Number of Immigrants', color = 'black', fontsize = '20')
plt.savefig('box_vertical.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# horizontal box plot

df_box.plot(kind = 'box', vert = False)
plt.title('Top 5 Immigrant Countries to Canada from 1980-2013', color = 'black')
plt.ylabel('Country', color = 'black')
plt.xlabel('Number of Immigrants', color = 'black')
plt.savefig('box_horizontal.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Scatter Plot
#
# With the newist version of Seaborn we have to specify x and y.
#
# example: sb.scatterplot(x = 'sepal_length', y = 'sepal_width', data = df_iris)

# %%
#scatter plot comparing sepal length to sepal width
import seaborn as sb
df_iris = sb.load_dataset('iris')

sb.scatterplot('sepal_length','sepal_width', data = df_iris, s = 200, linewidth = 3, edgecolor = 'b', color = '#FF10F0')
plt.title('Scatter Plot sample', color = 'black', fontsize = 20)
plt.savefig('scatter.png')

plt.show()
# Out:
# C:\Users\ortiz\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **The plots have a main color, and an edge color that can each be adjusted, neat.**

# %% [markdown]
# #### Histogram
#
# With the newist version of Seaborn they have deprecated distplot. Replace distplot with histplot and add kde = True
#
# example:
# sb.histplot(df_iris['sepal_length'], color = 'Red', label = 'Sepal Length', kde = True)

# %%
#Histogram side by side, with kde
df_iris = sb.load_dataset('iris')

sb.distplot(df_iris['sepal_length'], color = 'Red', label = 'Sepal Length')
sb.distplot(df_iris['sepal_width'], color = 'blue', label = 'Sepal Width')
plt.legend(fontsize = 12, labelcolor = 'black')
plt.xlabel('Sepal Width', color = 'black')
plt.ylabel('Frequency', color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('histogram.png')

plt.show()
# Out:
# C:\Users\ortiz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ortiz\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **color = does not work in plt.legend, the parameter name is labelcolor to change the text color**

# %% [markdown]
# #### Bubble Plot

# %%
# Bubble Plot

x = np.random.rand(1,30,1)
y = np.random.rand(1,30,1)
size = np.random.rand(1,30,1)

plt.scatter(x,y,s = size*4000, alpha = 0.4, color = 'lightblue', edgecolor = 'purple', linewidth = 4)
plt.title('Bubble Plot Sample', color = 'black')
plt.savefig('bubble.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **hotpink is a color that exists within the parameter options.**

# %% [markdown]
# #### Pie Chart
#
# Skip this one as the code throws an error.

# %% [markdown]
# df_pie = pd.DataFrame(df.groupby('continent')['total'].sum().T)
# colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
# explode = [0,0.1,0,0,0.1,0.1]
#
# plt.pie(df_pie, colors = colors, autopct = '%1.1f%%', startangle = 90, explode = explode, pctdistance = 1.12, shadow = True)
# plt.title('Continent-Wise Immigrants Distribution', color = 'black', y = 1.1, fontsize = 18)
# plt.legend(df_pie.index, loc = 'upper left', fontsize = 12)
# plt.axis('equal')
# plt.savefig('pie.png')
#
# plt.show()

# %% [markdown]
# #### Doughnut Chart

# %%
# Doughnut Chart
style.use('ggplot')
top5_list = df.nlargest(5, 'total').index.tolist()
df_top5 = pd.DataFrame(df.loc[top5_list, 'total'].T)
circle = plt.Circle( (0,0), 0.7, color='white')
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', '#C3B1E1', '#FFD1DC']

plt.pie(df_top5['total'], autopct = '%1.1f%%', shadow = True, explode = [0.1,0,0,0,0], colors = colors, startangle = 90)
fig = plt.gcf()
fig.gca().add_artist(circle)
plt.legend(df_top5.index, fontsize = 12, loc = 'upper left', labelcolor = 'hotpink')
plt.title('Top 5 Immigrant Country Distribution', color = 'black', fontsize = 18)
plt.axis('equal')
plt.savefig('doughnut.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
#
# **you can also use hex color codes, the lavender color is extremely pale, but the hex for **

# %% [markdown]
# #### Regression Plot

# %%
# Strong trend
df_reg = pd.DataFrame(df.loc['China',years])
df_reg.reset_index(inplace = True)
df_reg.rename(columns = {'index':'year'}, inplace = True)
df_reg[['year','China']] = df_reg[['year','China']].astype(int)

sb.regplot(x = 'year', y = 'China', data = df_reg, color = 'b', scatter_kws = {'s':150,'alpha':0.4})
plt.title('Total Immigration from China to Canada from 1980-2013', color = 'black')
plt.xlabel('Year', color = 'black')
plt.ylabel('Number of Immigrants', color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('reg_strong.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %%
# Weak trend
df_reg1 = pd.DataFrame(df.loc[['Denmark','Norway','Sweden'],years].sum())
df_reg1.reset_index(inplace = True)
df_reg1.rename(columns = {'index':'year',0:'total'}, inplace = True)
df_reg1[['year','total']] = df_reg1[['year','total']].astype(int)

sb.regplot(x = 'year', y = 'total', data = df_reg1, color = 'Red', scatter_kws = {'s':150,'alpha':0.4})
plt.title('Total Immigrants from Scandinavia to Canada from 1980-2013', color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Year', color = 'black')
plt.ylabel('Number of Immigrants', color = 'black')
plt.savefig('reg_weak.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>

# %% [markdown]
# #### Word Cloud
#
# You might need to pip install wordcloud and pip install Pywaffle.  Follow the instruction from when you installed cyperpunk earlier.
#
# Make sure to add the txt files from [here](https://github.com/codinglikeagirl42/DataVisualizationPython) to your data folder and remember the path is data/filename.txt. Try creating your own txt file to visualize.

# %%
# word cloud
from wordcloud import WordCloud, STOPWORDS

text = open('sample.txt', 'r', encoding = 'utf-8').read()
stopwords = set(STOPWORDS)
wordcloud = WordCloud(background_color = 'white', max_words = 200, stopwords = stopwords)

wordcloud.generate(text)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.savefig('wordcloud.png')

plt.show()
#further troubleshooting needed for pip install Pywaffle
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [79], in <cell line: 4>()
#       1 # word cloud
#       2 from wordcloud import WordCloud, STOPWORDS
# ----> 4 text = open('sample.txt', 'r', encoding = 'utf-8').read()
#       5 stopwords = set(STOPWORDS)
#       6 wordcloud = WordCloud(background_color = 'white', max_words = 200, stopwords = stopwords)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sample.txt'

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
# **I'm coming to stopping point here for this. After doing troubleshooting for the error when I tried to install Pywaffle:**
# *ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ortiz\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python310\\site-packages\\fontawesomefree\\static\\fontawesomefree\\js-packages\\@fortawesome\\fontawesome-free\\svgs\\brands\\creative-commons-sampling-plus.svg'
# HINT: This error might have occurred since this system does not have Windows Long Path support enabled. You can find information on how to enable this at https://pip.pypa.io/warnings/enable-long-paths*
#
# **I tried the option that it recommends to enable Windows Long Path but found that I have Windows 10 Home, and found an article that "Windows 10 Home Edition does not include group policy editor by default. If you run gpedit.msc, it will give you an error."**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Lollipop Chart

# %%
# Lollipop chart
plt.stem(df_tot.index, df_tot['total'])
plt.title('Total Immigrants to Canada from 1980-2013', color = 'black')
plt.xlabel('Year', color = 'black')
plt.ylabel('Number of Immigrants', color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.savefig('lollipop.png')

plt.show()

# %% [markdown]
# Feel free to experiment and add any notes or observations here. <br><br><br><br><br>
